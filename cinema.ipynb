# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
data = pd.read_csv("cinema_successful_orders.csv", encoding = "utf-8", sep=';', comment='#')
data
# Out:
#         order_id creation_date session_date  movie_id         movie_name  \
# 0        2441412    2020-03-07   2020-03-07     32452  Маленькие женщины
# 1        2169133    2020-02-03   2020-02-04     32452  Маленькие женщины
# 2        2187694    2020-02-06   2020-02-06     32452  Маленькие женщины
# 3        2182225    2020-02-05   2020-02-05     32452  Маленькие женщины
# 4        2209967    2020-02-08   2020-02-12     32452  Маленькие женщины
# ...          ...           ...          ...       ...                ...
# 525266   2289826    2020-02-17   2020-02-17     36247        Джентльмены
# 525267   2284126    2020-02-16   2020-02-16     36247        Джентльмены
# 525268   2371205    2020-02-25   2020-02-25     36247        Джентльмены
# 525269   2371601    2020-02-25   2020-02-25     36247        Джентльмены
# 525270   2368146    2020-02-24   2020-02-24     36247        Джентльмены
#
#        movie_duration movie_age_restriction movie_rating genre_is_triller  \
# ...

# %%
filtr_data = data[data['movie_rating']=='0,0']

# %%
data[data['movie_name']=='Джентльмены']
# Out:
#         order_id creation_date session_date  movie_id   movie_name  \
# 6137     2343947    2020-02-23   2020-02-23     33359  Джентльмены
# 6138     2406918    2020-03-01   2020-03-01     33359  Джентльмены
# 6139     2464443    2020-03-09   2020-03-09     33359  Джентльмены
# 6140     2315669    2020-02-20   2020-02-20     33359  Джентльмены
# 6141     2364320    2020-02-24   2020-02-25     33359  Джентльмены
# ...          ...           ...          ...       ...          ...
# 525266   2289826    2020-02-17   2020-02-17     36247  Джентльмены
# 525267   2284126    2020-02-16   2020-02-16     36247  Джентльмены
# 525268   2371205    2020-02-25   2020-02-25     36247  Джентльмены
# 525269   2371601    2020-02-25   2020-02-25     36247  Джентльмены
# 525270   2368146    2020-02-24   2020-02-24     36247  Джентльмены
#
#        movie_duration movie_age_restriction movie_rating genre_is_triller  \
# 6137              113                   18+         8,15              0,0
# ...

# %%
data['movie_name'].value_counts()
# Out:
# Джентльмены                                      78344
# Довод                                            56665
# Холоп                                            39573
# Лёд 2                                            22419
# 1917                                             21888
#                                                  ...
# ММКФ-2020: Безумный мир                              1
# Обыкновенный фашизм                                  1
# ММКФ-2020: Это не похороны, это — воскресение        1
# ММКФ-2020: COVID глазами молодых                     1
# Заводной апельсин                                    1
# Name: movie_name, Length: 1178, dtype: int64

# %%
djentelmen = data[data['movie_name']=='Джентльмены']
djentelmen.loc[djentelmen['movie_rating'] == '0,0', 'movie_rating'] = '8,15'
djentelmen
# Out:
#         order_id creation_date session_date  movie_id   movie_name  \
# 6137     2343947    2020-02-23   2020-02-23     33359  Джентльмены
# 6138     2406918    2020-03-01   2020-03-01     33359  Джентльмены
# 6139     2464443    2020-03-09   2020-03-09     33359  Джентльмены
# 6140     2315669    2020-02-20   2020-02-20     33359  Джентльмены
# 6141     2364320    2020-02-24   2020-02-25     33359  Джентльмены
# ...          ...           ...          ...       ...          ...
# 525266   2289826    2020-02-17   2020-02-17     36247  Джентльмены
# 525267   2284126    2020-02-16   2020-02-16     36247  Джентльмены
# 525268   2371205    2020-02-25   2020-02-25     36247  Джентльмены
# 525269   2371601    2020-02-25   2020-02-25     36247  Джентльмены
# 525270   2368146    2020-02-24   2020-02-24     36247  Джентльмены
#
#        movie_duration movie_age_restriction movie_rating genre_is_triller  \
# 6137              113                   18+         8,15              0,0
# ...

# %%
Beat Film Festival 2020. Закрытие
El Teatro Real: Билли Бадд                                                       0,0
El Teatro Real: Турандот                                                         0,0
Globe: Венецианский купец                                                        0,0
Globe: Двенадцатая ночь                                                         10,0
Globe: Доктор Фауст                                                              8,4
Globe: Укрощение строптивой                                                      0,0
Liceu Opera Barcelona: Донья Франсискита

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(data.groupby('movie_name')['movie_rating'].min())
# Out:
# movie_name
#  MIEFF 2021. Международный конкурс №1. «По ту сторону дверей»                    0,0
# (НЕ)идеальный мужчина                                                            5,0
# (Не)идеальный мужчина                                                            0,0
# 1+1                                                                              0,0
# 12 ребят, которые хотят умереть                                                  0,0
# 18+                                                                              0,0
# 1917                                                                             0,0
# 2040: Будущее ждет                                                               0,0
# 21 мост                                                                          0,0
# 4 лица Моны Лизы                                                                 0,0
# 40 лет Swans: Where Does a Body End?                                             0,0
# ...

# %%
data[data['movie_name']=='12 ребят, которые хотят умереть']
# Out:
#         order_id creation_date session_date  movie_id  \
# 64323    2096305    2020-01-23   2020-01-23     30232
# 71440    2044417    2020-01-13   2020-01-23     30232
# 124296   2092026    2020-01-22   2020-01-23     30232
# 151029   2090590    2020-01-22   2020-01-23     30232
# 179285   2091607    2020-01-22   2020-01-23     30232
# 181026   2044992    2020-01-13   2020-01-23     30232
#
#                              movie_name movie_duration movie_age_restriction  \
# 64323   12 ребят, которые хотят умереть       118 мин.                   18+
# 71440   12 ребят, которые хотят умереть       118 мин.                   18+
# 124296  12 ребят, которые хотят умереть       118 мин.                   18+
# 151029  12 ребят, которые хотят умереть       118 мин.                   18+
# 179285  12 ребят, которые хотят умереть       118 мин.                   18+
# 181026  12 ребят, которые хотят умереть       118 мин.                   18+
#
# ...

# %%
def japan(row):
    if row['movie_name'][:9]=='JapanFest':
        return row['movie_name']
    else:
        return a
data['japan'] = data.apply(japan, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16444\2199480662.py in <module>
#       5     else:
#       6         return a
# ----> 7 data['japan'] = data.apply(japan, axis=1)
#       8
#
# D:\Jupyter\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# D:\Jupyter\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# D:\Jupyter\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# ...

# %%
data.iloc[100]['movie_name'][:8]
# Out:
# 'Соник в '

# %%
skazka = data[data['genre_is_western']=='1,0']
skazka['number_of_tickets'].mean()
# Out:
# 1.8529411764705883

# %%
skazka.groupby('movie_name')['number_of_tickets'].agg('mean')
# Out:
# movie_name
# 1917                          1.975649
# 21 мост                       2.000000
# AmFest-2020: Аммонит          1.548387
# AmFest-2020: Глории           1.777778
# AmFest-2020: Девять дней      1.341463
#                                 ...
# Эскобар                       1.000000
# Это всего лишь конец света    1.000000
# Я свободен                    2.000000
# Явление                       2.166667
# Ярды                          2.000000
# Name: number_of_tickets, Length: 372, dtype: float64

# %%
data.value_counts('session_date').iloc[0:50]
# Out:
# session_date
# 2020-02-23    14038
# 2020-02-15    13151
# 2020-02-16    12185
# 2020-02-22    10899
# 2020-02-24    10501
# 2020-03-08    10457
# 2020-02-14    10016
# 2020-01-02     9235
# 2020-01-03     8525
# 2020-02-01     8366
# 2020-02-08     8335
# 2020-02-29     8007
# 2020-01-04     7904
# 2020-02-02     7826
# 2020-01-25     7654
# 2020-01-05     7604
# 2020-03-07     7267
# 2020-01-07     7140
# 2020-02-09     7027
# 2020-01-11     6803
# 2020-03-01     6783
# 2020-01-06     6697
# 2020-01-18     6644
# 2020-03-09     6515
# 2020-01-26     6375
# 2020-01-01     5962
# 2020-01-12     5939
# 2020-01-19     5584
# 2020-01-08     5551
# 2020-03-14     5442
# 2020-09-12     5347
# 2020-02-18     5029
# 2020-02-19     4989
# 2020-02-21     4801
# 2020-09-05     4692
# 2020-09-13     4581
# 2020-02-04     4526
# 2020-03-15     4368
# 2020-02-17     4299
# 2020-02-07     4292
# 2020-02-25     4286
# 2020-09-19     4223
# 2020-09-06     4011
# 2020-01-31     3994
# ...

# %%
data.value_counts('cinema_city')
# Out:
# cinema_city
# Москва             189364
# Санкт-Петербург     68293
# Казань              16718
# Екатеринбург        15818
# Ростов-на-Дону      11395
#                     ...
# Волжский                1
# Усть-Илимск             1
# Венев                   1
# Губкинский              1
# Елец                    1
# Length: 233, dtype: int64

# %%
def rating(row):
    if row['movie_rating'] == '0,0':
        
        return data[data['movie_name']==row['movie_name']]['movie_rating'].max()
    else:
        return '0'
data['new_rait'] == data.apply(rating, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Jupyter\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\Jupyter\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Jupyter\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_rait'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
if data[data['movie_name']=='21 мост']['movie_rating'].min() == '0,0':
    print('lg')
# Out:
# lg

# %%
data[data['movie_id']==36247]
# Out:
#         order_id creation_date session_date  movie_id   movie_name  \
# 26339    2336828    2020-02-22   2020-02-23     36247  Джентльмены
# 26340    2311030    2020-02-20   2020-02-20     36247  Джентльмены
# 27685    2372360    2020-02-25   2020-02-25     36247  Джентльмены
# 27686    2362545    2020-02-24   2020-02-24     36247  Джентльмены
# 27687    2313489    2020-02-20   2020-02-20     36247  Джентльмены
# ...          ...           ...          ...       ...          ...
# 525266   2289826    2020-02-17   2020-02-17     36247  Джентльмены
# 525267   2284126    2020-02-16   2020-02-16     36247  Джентльмены
# 525268   2371205    2020-02-25   2020-02-25     36247  Джентльмены
# 525269   2371601    2020-02-25   2020-02-25     36247  Джентльмены
# 525270   2368146    2020-02-24   2020-02-24     36247  Джентльмены
#
#        movie_duration movie_age_restriction movie_rating genre_is_triller  \
# 26339             113                   18+          0,0              0,0
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(data[data['movie_name']=='MIEFF 2020: Закрытие фестиваля и показ фильмов-победителей'])
# Out:
#         order_id creation_date session_date  movie_id  \
# 48361    2539137    2020-08-23   2020-08-25     48909
# 48655    2539341    2020-08-24   2020-08-25     48909
# 55435    2537779    2020-08-22   2020-08-25     48909
# 157821   2539350    2020-08-24   2020-08-25     48909
# 164700   2538554    2020-08-23   2020-08-25     48909
# 164702   2534374    2020-08-18   2020-08-25     48909
#
#                                                movie_name movie_duration  \
# 48361   MIEFF 2020: Закрытие фестиваля и показ фильмов...            NaN
# 48655   MIEFF 2020: Закрытие фестиваля и показ фильмов...            NaN
# 55435   MIEFF 2020: Закрытие фестиваля и показ фильмов...            NaN
# 157821  MIEFF 2020: Закрытие фестиваля и показ фильмов...            NaN
# 164700  MIEFF 2020: Закрытие фестиваля и показ фильмов...            NaN
# 164702  MIEFF 2020: Закрытие фестиваля и показ фильмов...            NaN
#
# ...
